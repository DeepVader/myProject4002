# %%
import pandas as pd

pd.options.display.float_format = "{:,.2f}".format

# %% [markdown]
# # read data

# %%
orders_df = pd.read_csv('./datasorce/List of Orders.csv')
order_details_df = pd.read_csv('./datasorce/Order Details.csv')
sales_targets_df = pd.read_csv('./datasorce/Sales target.csv')

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      500 non-null    object
#  1   Order Date    500 non-null    object
#  2   CustomerName  500 non-null    object
#  3   State         500 non-null    object
#  4   City          500 non-null    object
# dtypes: object(5)
# memory usage: 22.0+ KB

# %%
orders_df = orders_df.dropna();
orders_df
# Out:
#     Order ID  Order Date CustomerName              State       City
# 0    B-25601  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl        Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha          Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen        West Bengal    Kolkata
# ..       ...         ...          ...                ...        ...
# 495  B-26096  28-03-2019       Atharv        West Bengal    Kolkata
# 496  B-26097  28-03-2019         Vini          Karnataka  Bangalore
# 497  B-26098  29-03-2019        Pinky  Jammu and Kashmir    Kashmir
# 498  B-26099  30-03-2019       Bhishm        Maharashtra     Mumbai
# 499  B-26100  31-03-2019       Hitika     Madhya Pradesh     Indore
#
# [500 rows x 5 columns]

# %%
CustomerNameUnique = orders_df['CustomerName'].unique()
print(CustomerNameUnique, len(CustomerNameUnique))
# Out:
# ['Bharat' 'Pearl' 'Jahan' 'Divsha' 'Kasheen' 'Hazel' 'Sonakshi' 'Aarushi'
#  'Jitesh' 'Yogesh' 'Anita' 'Shrichand' 'Mukesh' 'Vandana' 'Bhavna' 'Kanak'
#  'Sagar' 'Manju' 'Ramesh' 'Sarita' 'Deepak' 'Monisha' 'Atharv' 'Vini'
#  'Pinky' 'Bhishm' 'Hitika' 'Pooja' 'Hemant' 'Sahil' 'Ritu' 'Manish' 'Amit'
#  'Sanjay' 'Nidhi' 'Nishi' 'Ashmi' 'Parth' 'Lisha' 'Paridhi' 'Parishi'
#  'Ajay' 'Kirti' 'Mayank' 'Yaanvi' 'Sonal' 'Sharda' 'Aditya' 'Rachna'
#  'Chirag' 'Anurag' 'Tushina' 'Farah' 'Sabah' 'Nida' 'Priyanka' 'Tulika'
#  'Shefali' 'Sanskriti' 'Shruti' 'Subhashree' 'Sweta' 'Pournamasi'
#  'Pratyusmita' 'Chayanika' 'Tanvi' 'Anjali' 'Rhea' 'Piyali' 'Charika'
#  'Mitali' 'Akanksha' 'Arsheen' 'Mahima' 'Shreya' 'Chandni' 'Ekta'
#  'Bathina' 'Avni' 'Aayushi' 'Bhawna' 'Krutika' 'Samiksha' 'Sheetal'
#  'Sanjna' 'Swetha' 'Bhaggyasree' 'Gunjan' 'Akancha' 'Rashmi' 'Parna'
#  'Subhasmita' 'Suhani' 'Noopur' 'Vijay' 'Amisha' 'Kritika' 'Shubhi'
# ...

# %%
StateUnique = orders_df['State'].unique()
print(StateUnique, len(StateUnique))
# Out:
# ['Gujarat' 'Maharashtra' 'Madhya Pradesh' 'Rajasthan' 'West Bengal'
#  'Karnataka' 'Jammu and Kashmir' 'Tamil Nadu' 'Uttar Pradesh' 'Bihar'
#  'Kerala ' 'Punjab' 'Haryana' 'Himachal Pradesh' 'Sikkim' 'Goa' 'Nagaland'
#  'Andhra Pradesh' 'Delhi'] 19

# %%
CityUnique = orders_df['City'].unique()
print(CityUnique, len(CityUnique))
# Out:
# ['Ahmedabad' 'Pune' 'Bhopal' 'Jaipur' 'Kolkata' 'Bangalore' 'Kashmir'
#  'Chennai' 'Lucknow' 'Patna' 'Thiruvananthapuram' 'Chandigarh' 'Simla'
#  'Gangtok' 'Goa' 'Kohima' 'Hyderabad' 'Mumbai' 'Indore' 'Surat' 'Udaipur'
#  'Allahabad' 'Amritsar' 'Delhi'] 24

# %%
order_details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Amount        1500 non-null   float64
#  2   Profit        1500 non-null   float64
#  3   Quantity      1500 non-null   int64
#  4   Category      1500 non-null   object
#  5   Sub-Category  1500 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 70.4+ KB

# %%
CategoryUnique = order_details_df['Category'].unique()
print(CategoryUnique, len(CategoryUnique))
# Out:
# ['Furniture' 'Clothing' 'Electronics'] 3

# %%
SubCategoryUnique = order_details_df['Sub-Category'].unique()
print(SubCategoryUnique, len(SubCategoryUnique))
# Out:
# ['Bookcases' 'Stole' 'Hankerchief' 'Electronic Games' 'Phones' 'Saree'
#  'Trousers' 'Chairs' 'Kurti' 'T-shirt' 'Shirt' 'Leggings' 'Tables'
#  'Printers' 'Accessories' 'Furnishings' 'Skirt'] 17

# %%
sales_targets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month of Order Date  36 non-null     object
#  1   Category             36 non-null     object
#  2   Target               36 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 996.0+ bytes

# %% [markdown]
# # transform

# %%
customers_df = orders_df[["CustomerName", "State", "City"]].drop_duplicates().reset_index(drop=True)
customers_df["Customer ID"] = customers_df.index + 1

customers_df = customers_df[["Customer ID", "CustomerName", "State", "City"]]
customers_df
# Out:
#      Customer ID CustomerName              State       City
# 0              1       Bharat            Gujarat  Ahmedabad
# 1              2        Pearl        Maharashtra       Pune
# 2              3        Jahan     Madhya Pradesh     Bhopal
# 3              4       Divsha          Rajasthan     Jaipur
# 4              5      Kasheen        West Bengal    Kolkata
# ..           ...          ...                ...        ...
# 396          397      Shubham  Jammu and Kashmir    Kashmir
# 397          398      Kalyani         Tamil Nadu    Chennai
# 398          399        Komal      Uttar Pradesh    Lucknow
# 399          400     Kartikay              Bihar      Patna
# 400          401       Ankita        Maharashtra     Mumbai
#
# [401 rows x 4 columns]

# %%
old_to_new = {j: i+1 for i, j in enumerate(orders_df['Order ID'])}
old_to_new
# Out:
# {'B-25601': 1,
#  'B-25602': 2,
#  'B-25603': 3,
#  'B-25604': 4,
#  'B-25605': 5,
#  'B-25606': 6,
#  'B-25607': 7,
#  'B-25608': 8,
#  'B-25609': 9,
#  'B-25610': 10,
#  'B-25611': 11,
#  'B-25612': 12,
#  'B-25613': 13,
#  'B-25614': 14,
#  'B-25615': 15,
#  'B-25616': 16,
#  'B-25617': 17,
#  'B-25618': 18,
#  'B-25619': 19,
#  'B-25620': 20,
#  'B-25621': 21,
#  'B-25622': 22,
#  'B-25623': 23,
#  'B-25624': 24,
#  'B-25625': 25,
#  'B-25626': 26,
#  'B-25627': 27,
#  'B-25628': 28,
#  'B-25629': 29,
#  'B-25630': 30,
#  'B-25631': 31,
#  'B-25632': 32,
#  'B-25633': 33,
#  'B-25634': 34,
#  'B-25635': 35,
#  'B-25636': 36,
#  'B-25637': 37,
#  'B-25638': 38,
#  'B-25639': 39,
#  'B-25640': 40,
#  'B-25641': 41,
#  'B-25642': 42,
#  'B-25643': 43,
#  'B-25644': 44,
#  'B-25645': 45,
#  'B-25646': 46,
#  'B-25647': 47,
#  'B-25648': 48,
#  'B-25649': 49,
#  'B-25650': 50,
#  'B-25651': 51,
#  'B-25652': 52,
#  'B-25653': 53,
#  'B-25654': 54,
#  'B-25655': 55,
#  'B-25656': 56,
# ...

# %%
orders_df["Customer ID"] = orders_df.merge(customers_df, on=["CustomerName", "State", "City"])["Customer ID"]
orders_table = orders_df[["Order ID", "Order Date", "Customer ID"]]
orders_table["Order ID"] = orders_table.index + 1

orders_table
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_18844\1252971040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_table["Order ID"] = orders_table.index + 1
#      Order ID  Order Date  Customer ID
# 0           1  01-04-2018            1
# 1           2  01-04-2018            2
# 2           3  03-04-2018            3
# 3           4  03-04-2018            4
# 4           5  05-04-2018            5
# ..        ...         ...          ...
# 495       496  28-03-2019           23
# 496       497  28-03-2019           24
# 497       498  29-03-2019           25
# 498       499  30-03-2019           26
# 499       500  31-03-2019           27
#
# [500 rows x 3 columns]

# %%
categories_df = order_details_df[["Category"]].drop_duplicates().reset_index(drop=True)
categories_df["Category ID"] = categories_df.index + 1

categories_df = categories_df[["Category ID", "Category"]]
categories_df
# Out:
#    Category ID     Category
# 0            1    Furniture
# 1            2     Clothing
# 2            3  Electronics

# %%
subcategories_df = order_details_df[["Sub-Category", "Category"]].drop_duplicates().reset_index(drop=True)
subcategories_df = subcategories_df.merge(categories_df, on="Category")
subcategories_df["Sub-Category ID"] = subcategories_df.index + 1
subcategories_df = subcategories_df.drop('Category', axis='columns')

subcategories_df = subcategories_df[["Sub-Category ID", "Sub-Category", "Category ID"]]
subcategories_df
# Out:
#     Sub-Category ID      Sub-Category  Category ID
# 0                 1         Bookcases            1
# 1                 2             Stole            2
# 2                 3       Hankerchief            2
# 3                 4  Electronic Games            3
# 4                 5            Phones            3
# 5                 6             Saree            2
# 6                 7          Trousers            2
# 7                 8            Chairs            1
# 8                 9             Kurti            2
# 9                10           T-shirt            2
# 10               11             Shirt            2
# 11               12          Leggings            2
# 12               13            Tables            1
# 13               14          Printers            3
# 14               15       Accessories            3
# 15               16       Furnishings            1
# 16               17             Skirt            2

# %%
order_details_table = order_details_df.merge(
    subcategories_df[["Sub-Category", "Sub-Category ID"]],
    on="Sub-Category"
)
order_details_table["Order ID"] = order_details_table["Order ID"].map(old_to_new)
order_details_table["Detail ID"] = order_details_table.index + 1

order_details_table = order_details_table[["Detail ID", "Order ID", "Amount", "Profit", "Quantity", "Sub-Category ID"]]
order_details_table
# Out:
#       Detail ID  Order ID   Amount    Profit  Quantity  Sub-Category ID
# 0             1         1 1,275.00 -1,148.00         7                1
# 1             2         1    66.00    -12.00         5                2
# 2             3         1     8.00     -2.00         3                3
# 3             4         1    80.00    -56.00         4                4
# 4             5         2   168.00   -111.00         2                5
# ...         ...       ...      ...       ...       ...              ...
# 1495       1496       499   835.00    267.00         5                5
# 1496       1497       499 2,366.00    552.00         5                7
# 1497       1498       500   828.00    230.00         2                8
# 1498       1499       500    34.00     10.00         2               10
# 1499       1500       500    72.00     16.00         2               11
#
# [1500 rows x 6 columns]

# %%
sales_targets_table = sales_targets_df.merge(
    categories_df, left_on="Category", right_on="Category"
)
sales_targets_table = sales_targets_table[["Month of Order Date", "Category ID", "Target"]]
sales_targets_table["Target ID"] = sales_targets_table.index + 1

sales_targets_table = sales_targets_table[["Target ID", "Month of Order Date", "Category ID", "Target"]]
sales_targets_table
# Out:
#     Target ID Month of Order Date  Category ID    Target
# 0           1              Apr-18            1 10,400.00
# 1           2              May-18            1 10,500.00
# 2           3              Jun-18            1 10,600.00
# 3           4              Jul-18            1 10,800.00
# 4           5              Aug-18            1 10,900.00
# 5           6              Sep-18            1 11,000.00
# 6           7              Oct-18            1 11,100.00
# 7           8              Nov-18            1 11,300.00
# 8           9              Dec-18            1 11,400.00
# 9          10              Jan-19            1 11,500.00
# 10         11              Feb-19            1 11,600.00
# 11         12              Mar-19            1 11,800.00
# 12         13              Apr-18            2 12,000.00
# 13         14              May-18            2 12,000.00
# 14         15              Jun-18            2 12,000.00
# ...

# %% [markdown]
# # data type transform

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Customer ID   401 non-null    int64
#  1   CustomerName  401 non-null    object
#  2   State         401 non-null    object
#  3   City          401 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 12.7+ KB

# %%
customers_df = customers_df.astype({
    "CustomerName": "string",
    "State": "string",
    "City": "string"
    })

customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Customer ID   401 non-null    int64
#  1   CustomerName  401 non-null    string
#  2   State         401 non-null    string
#  3   City          401 non-null    string
# dtypes: int64(1), string(3)
# memory usage: 12.7 KB

# %%
orders_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order ID     500 non-null    int64
#  1   Order Date   500 non-null    object
#  2   Customer ID  500 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 15.6+ KB

# %%
orders_table["Order Date"] = pd.to_datetime(orders_table["Order Date"], format='%d-%m-%Y').dt.strftime('%Y-%m-%d')

orders_table
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_18844\719462685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_table["Order Date"] = pd.to_datetime(orders_table["Order Date"], format='%d-%m-%Y').dt.strftime('%Y-%m-%d')
#      Order ID  Order Date  Customer ID
# 0           1  2018-04-01            1
# 1           2  2018-04-01            2
# 2           3  2018-04-03            3
# 3           4  2018-04-03            4
# 4           5  2018-04-05            5
# ..        ...         ...          ...
# 495       496  2019-03-28           23
# 496       497  2019-03-28           24
# 497       498  2019-03-29           25
# 498       499  2019-03-30           26
# 499       500  2019-03-31           27
#
# [500 rows x 3 columns]

# %%
categories_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category ID  3 non-null      int64
#  1   Category     3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
categories_df = categories_df.astype({
    "Category": "string"
})

categories_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category ID  3 non-null      int64
#  1   Category     3 non-null      string
# dtypes: int64(1), string(1)
# memory usage: 180.0 bytes

# %%
subcategories_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sub-Category ID  17 non-null     int64
#  1   Sub-Category     17 non-null     object
#  2   Category ID      17 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 540.0+ bytes

# %%
subcategories_df = subcategories_df.astype({
    "Sub-Category": "string",
})

subcategories_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sub-Category ID  17 non-null     int64
#  1   Sub-Category     17 non-null     string
#  2   Category ID      17 non-null     int64
# dtypes: int64(2), string(1)
# memory usage: 540.0 bytes

# %%
order_details_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Detail ID        1500 non-null   int64
#  1   Order ID         1500 non-null   int64
#  2   Amount           1500 non-null   float64
#  3   Profit           1500 non-null   float64
#  4   Quantity         1500 non-null   int64
#  5   Sub-Category ID  1500 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 70.4 KB

# %%
order_details_table = order_details_table.astype({
    "Order ID": "int",
})

order_details_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Detail ID        1500 non-null   int64
#  1   Order ID         1500 non-null   int32
#  2   Amount           1500 non-null   float64
#  3   Profit           1500 non-null   float64
#  4   Quantity         1500 non-null   int64
#  5   Sub-Category ID  1500 non-null   int64
# dtypes: float64(2), int32(1), int64(3)
# memory usage: 64.6 KB

# %%
sales_targets_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Target ID            36 non-null     int64
#  1   Month of Order Date  36 non-null     object
#  2   Category ID          36 non-null     int64
#  3   Target               36 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.3+ KB

# %%
sales_targets_table
# Out:
#     Target ID Month of Order Date  Category ID    Target
# 0           1              Apr-18            1 10,400.00
# 1           2              May-18            1 10,500.00
# 2           3              Jun-18            1 10,600.00
# 3           4              Jul-18            1 10,800.00
# 4           5              Aug-18            1 10,900.00
# 5           6              Sep-18            1 11,000.00
# 6           7              Oct-18            1 11,100.00
# 7           8              Nov-18            1 11,300.00
# 8           9              Dec-18            1 11,400.00
# 9          10              Jan-19            1 11,500.00
# 10         11              Feb-19            1 11,600.00
# 11         12              Mar-19            1 11,800.00
# 12         13              Apr-18            2 12,000.00
# 13         14              May-18            2 12,000.00
# 14         15              Jun-18            2 12,000.00
# ...

# %%
sales_targets_table['Month of Order Date'] = pd.to_datetime(sales_targets_table['Month of Order Date'], format='%b-%y').dt.strftime('%Y-%m-%d')

sales_targets_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Target ID            36 non-null     int64
#  1   Month of Order Date  36 non-null     object
#  2   Category ID          36 non-null     int64
#  3   Target               36 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.3+ KB

# %%
sales_targets_table.head()
# Out:
#    Target ID Month of Order Date  Category ID    Target
# 0          1          2018-04-01            1 10,400.00
# 1          2          2018-05-01            1 10,500.00
# 2          3          2018-06-01            1 10,600.00
# 3          4          2018-07-01            1 10,800.00
# 4          5          2018-08-01            1 10,900.00

# %% [markdown]
# # digits

# %%
order_details_table.head()
# Out:
#    Detail ID  Order ID   Amount    Profit  Quantity  Sub-Category ID
# 0          1         1 1,275.00 -1,148.00         7                1
# 1          2         1    66.00    -12.00         5                2
# 2          3         1     8.00     -2.00         3                3
# 3          4         1    80.00    -56.00         4                4
# 4          5         2   168.00   -111.00         2                5

# %%
order_details_table['Amount'] = order_details_table['Amount'].round(2)
order_details_table['Profit'] = order_details_table['Profit'].round(2)

order_details_table.head()
# Out:
#    Detail ID  Order ID   Amount    Profit  Quantity  Sub-Category ID
# 0          1         1 1,275.00 -1,148.00         7                1
# 1          2         1    66.00    -12.00         5                2
# 2          3         1     8.00     -2.00         3                3
# 3          4         1    80.00    -56.00         4                4
# 4          5         2   168.00   -111.00         2                5

# %%
sales_targets_table.head()
# Out:
#    Target ID Month of Order Date  Category ID    Target
# 0          1          2018-04-01            1 10,400.00
# 1          2          2018-05-01            1 10,500.00
# 2          3          2018-06-01            1 10,600.00
# 3          4          2018-07-01            1 10,800.00
# 4          5          2018-08-01            1 10,900.00

# %%
sales_targets_table['Target'] = sales_targets_table['Target'].round(2)

sales_targets_table.head()
# Out:
#    Target ID Month of Order Date  Category ID    Target
# 0          1          2018-04-01            1 10,400.00
# 1          2          2018-05-01            1 10,500.00
# 2          3          2018-06-01            1 10,600.00
# 3          4          2018-07-01            1 10,800.00
# 4          5          2018-08-01            1 10,900.00

# %% [markdown]
# # rename columns

# %%
customers_df.rename(columns={"Customer ID": "Customer_ID", "CustomerName": "Customer_Name"}, inplace=True)
customers_df
# Out:
#      Customer_ID Customer_Name              State       City
# 0              1        Bharat            Gujarat  Ahmedabad
# 1              2         Pearl        Maharashtra       Pune
# 2              3         Jahan     Madhya Pradesh     Bhopal
# 3              4        Divsha          Rajasthan     Jaipur
# 4              5       Kasheen        West Bengal    Kolkata
# ..           ...           ...                ...        ...
# 396          397       Shubham  Jammu and Kashmir    Kashmir
# 397          398       Kalyani         Tamil Nadu    Chennai
# 398          399         Komal      Uttar Pradesh    Lucknow
# 399          400      Kartikay              Bihar      Patna
# 400          401        Ankita        Maharashtra     Mumbai
#
# [401 rows x 4 columns]

# %%
orders_table.rename(columns={"Order ID": "Order_ID", "Customer ID": "Customer_ID", "Order Date": "Order_Date"}, inplace=True)
orders_table
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_18844\2767669379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_table.rename(columns={"Order ID": "Order_ID", "Customer ID": "Customer_ID", "Order Date": "Order_Date"}, inplace=True)
#      Order_ID  Order_Date  Customer_ID
# 0           1  2018-04-01            1
# 1           2  2018-04-01            2
# 2           3  2018-04-03            3
# 3           4  2018-04-03            4
# 4           5  2018-04-05            5
# ..        ...         ...          ...
# 495       496  2019-03-28           23
# 496       497  2019-03-28           24
# 497       498  2019-03-29           25
# 498       499  2019-03-30           26
# 499       500  2019-03-31           27
#
# [500 rows x 3 columns]

# %%
categories_df.rename(columns={"Category ID": "Category_ID", "Category": "Category_Name"}, inplace=True)
categories_df
# Out:
#    Category_ID Category_Name
# 0            1     Furniture
# 1            2      Clothing
# 2            3   Electronics

# %%
subcategories_df.rename(columns={"Sub-Category ID": "SubCategory_ID", "Sub-Category": "SubCategory_Name", "Category ID": "Category_ID"}, inplace=True)
subcategories_df
# Out:
#     SubCategory_ID  SubCategory_Name  Category_ID
# 0                1         Bookcases            1
# 1                2             Stole            2
# 2                3       Hankerchief            2
# 3                4  Electronic Games            3
# 4                5            Phones            3
# 5                6             Saree            2
# 6                7          Trousers            2
# 7                8            Chairs            1
# 8                9             Kurti            2
# 9               10           T-shirt            2
# 10              11             Shirt            2
# 11              12          Leggings            2
# 12              13            Tables            1
# 13              14          Printers            3
# 14              15       Accessories            3
# 15              16       Furnishings            1
# 16              17             Skirt            2

# %%
order_details_table.rename(columns={"Detail ID": "Detail_ID", "Order ID": "Order_ID", "Sub-Category ID": "SubCategory_ID"}, inplace=True)
order_details_table
# Out:
#       Detail_ID  Order_ID   Amount    Profit  Quantity  SubCategory_ID
# 0             1         1 1,275.00 -1,148.00         7               1
# 1             2         1    66.00    -12.00         5               2
# 2             3         1     8.00     -2.00         3               3
# 3             4         1    80.00    -56.00         4               4
# 4             5         2   168.00   -111.00         2               5
# ...         ...       ...      ...       ...       ...             ...
# 1495       1496       499   835.00    267.00         5               5
# 1496       1497       499 2,366.00    552.00         5               7
# 1497       1498       500   828.00    230.00         2               8
# 1498       1499       500    34.00     10.00         2              10
# 1499       1500       500    72.00     16.00         2              11
#
# [1500 rows x 6 columns]

# %%
sales_targets_table.rename(columns={"Target ID": "Target_ID", "Month of Order Date": "MonthOfOrderDate", "Category ID": "Category_ID"}, inplace=True)
sales_targets_table
# Out:
#     Target_ID MonthOfOrderDate  Category_ID    Target
# 0           1       2018-04-01            1 10,400.00
# 1           2       2018-05-01            1 10,500.00
# 2           3       2018-06-01            1 10,600.00
# 3           4       2018-07-01            1 10,800.00
# 4           5       2018-08-01            1 10,900.00
# 5           6       2018-09-01            1 11,000.00
# 6           7       2018-10-01            1 11,100.00
# 7           8       2018-11-01            1 11,300.00
# 8           9       2018-12-01            1 11,400.00
# 9          10       2019-01-01            1 11,500.00
# 10         11       2019-02-01            1 11,600.00
# 11         12       2019-03-01            1 11,800.00
# 12         13       2018-04-01            2 12,000.00
# 13         14       2018-05-01            2 12,000.00
# 14         15       2018-06-01            2 12,000.00
# 15         16       2018-07-01            2 14,000.00
# ...

# %% [markdown]
# # save csv

# %%
customers_df.to_csv('./datatrans/customers_df.csv', index=False)
orders_table.to_csv('./datatrans/orders_table.csv', index=False)
categories_df.to_csv('./datatrans/categories_df.csv', index=False)
subcategories_df.to_csv('./datatrans/subcategories_df.csv', index=False)
order_details_table.to_csv('./datatrans/order_details_table.csv', index=False)
sales_targets_table.to_csv('./datatrans/sales_targets_table.csv', index=False)
