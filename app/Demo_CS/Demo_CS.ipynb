# %%
from conn import create_connection
conn = create_connection()

def Customer_detail():
    while True:
        print("="*50)
        print("Customer Detail".center(50, " "))
        print("="*50)

        print("1.Customer Segmentation")
        print("2.Customer Purchase Behavior")
        print("3.Demographic Trends")

        print("="*50)
        print("0.Back to admin")
        print("="*50)
        choice = input("_Select an option: ")

        if choice == "1":
            from cs_segment import Customer_Segment
            Customer_Segment(conn)
        elif choice == "2":
            from cs_purchase import Customer_Purchase
            Customer_Purchase(conn)
        elif choice == "3":
            from cs_demographic import Demographic_Trends
            Demographic_Trends(conn)
        elif choice == "0":
            adminMenu_display() #กลับไปเมนูหลัก
            break

Customer_detail()
# Out:
# ---------------------
# Connection successful
# ---------------------
# ...
#                  Customer Detail
# ...
# 1.Customer Segmentation
# 2.Customer Purchase Behavior
# 3.Demographic Trends
# ...
# 0.Back to admin
# ...
#                 Demographic Trends
#            Total customer = 401 persons
# ...
# +-------------------+---------------+----------------+
# |       State       | Category Name | Total Quantity |
# +-------------------+---------------+----------------+
# |   Madhya Pradesh  |    Clothing   |     857.0      |
# |   Madhya Pradesh  |   Furniture   |     256.0      |
# |   Madhya Pradesh  |  Electronics  |     247.0      |
# |    Maharashtra    |    Clothing   |     595.0      |
# |    Maharashtra    |  Electronics  |     264.0      |
# |    Maharashtra    |   Furniture   |     197.0      |
# |      Gujarat      |    Clothing   |     239.0      |
# |      Gujarat      |   Furniture   |      58.0      |
# |      Gujarat      |  Electronics  |      31.0      |
# ...
